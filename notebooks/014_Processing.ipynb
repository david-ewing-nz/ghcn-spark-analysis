# %% [markdown]
# ### Spark notebook ###
#
# This notebook will only work in a Jupyter notebook or Jupyter lab session running on the cluster master node in the cloud.
#
# Follow the instructions on the computing resources page to start a cluster and open this notebook.
#
# **Steps**
#
# 1. Connect to the Windows server using Windows App.
# 2. Connect to Kubernetes.
# 3. Start Jupyter and open this notebook from Jupyter in order to connect to Spark.

# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Constants used to interact with Azure Blob Storage using the hdfs command or Spark

global username

username = re.sub('@.*', '', getpass.getuser())

global azure_account_name
global azure_data_container_name
global azure_user_container_name
global azure_user_token

azure_account_name = "madsstorage002"
azure_data_container_name = "campus-data"
azure_user_container_name = "campus-user"
azure_user_token = r"sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D"

# Student functions 

def pprint_sc_context(sc):
    print("Spark App:", sc.appName)
    print("Master   :", sc.master)
    print("UI       :", sc.uiWebUrl)
    print("Version  :", sc.version)
    print("\nSpark Config:")
    for k, v in sc.getConf().getAll():
        print(f"{k} = {v}")
        



    

# Functions used below

def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

    
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")

        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://localhost:{sc.uiWebUrl.split(":")[-1]}" target="_blank">Spark Application UI</a></li>',
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username} (notebook)</code> is under the completed applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{username}/spark/")
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.driver.memory", f'{master_memory}g')
        .config("spark.executor.memory", f'{worker_memory}g')
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.kubernetes.container.image", "madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8")
        .config("spark.kubernetes.container.image.pullPolicy", "IfNotPresent")
        .config("spark.kubernetes.memoryOverheadFactor", "0.3")
        .config("spark.memory.fraction", "0.1")
        .config(f"fs.azure.sas.{azure_user_container_name}.{azure_account_name}.blob.core.windows.net",  azure_user_token)
        .config("spark.app.name", f"{username} (notebook)")
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()
    pprint_sc_context(sc) #DEE: 
    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        pprint_sc_context(sc) #DEE:
        spark.stop()

        pprint_sc_context(sc) #DEE:
        del spark
        del sc

    display_spark()

# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))
# Out:
# <style>pre { white-space: pre !important; }table.dataframe td { white-space: nowrap !important; }table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }</style>

# %% [markdown]
# ### Assignment 1 ###
#
# The code below demonstrates how to explore and load the data provided for the assignment from Azure Blob Storage and how to save any outputs that you generate to a separate user container.
#
# **Key points**
#
# - The data provided for the assignment is stored in Azure Blob Storage and outputs that you generate will be stored in Azure Blob Storage as well. Hadoop and Spark can both interact with Azure Blob Storage similar to how they interact with HDFS, but where the replication and distribution is handled by Azure instead. This makes it possible to read or write data in Azure over HTTPS where the path is prefixed by `wasbs://`.
# - There are two containers, one for the data which is read only and one for any outputs that you generate,
#   - `wasbs://campus-data@madsstorage002.blob.core.windows.net/`
#   - `wasbs://campus-user@madsstorage002.blob.core.windows.net/`
# - You can use variable interpolation to insert your global username variable into paths automatically.
#   - This works for bash commands as well.

# %%
# Run this cell to start a spark session in this notebook

start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1)
pprint_sc_context(sc)
# Out:
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:green">active</span></b>, look for <code>dew59 (notebook)</code> under the running applications section in the Spark UI.</p><ul><li><a href="http://localhost:4045" target="_blank">Spark Application UI</a></li></ul><p><b>Config</b></p><table width="100%" style="width:100%; font-family: monospace;"><tr><td style="text-align:left;">spark.kubernetes.executor.podNamePrefix</td><td>dew59-notebook-741e2595def4ed26</td></tr><tr><td style="text-align:left;">spark.dynamicAllocation.enabled</td><td>false</td></tr><tr><td style="text-align:left;">spark.fs.azure.sas.uco-user.madsstorage002.blob.core.windows.net</td><td>"sp=racwdl&st=2024-09-19T08:00:18Z&se=2025-09-19T16:00:18Z&spr=https&sv=2022-11-02&sr=c&sig=qtg6fCdoFz6k3EJLw7dA8D3D8wN0neAYw8yG4z4Lw2o%3D"</td></tr><tr><td style="text-align:left;">spark.kubernetes.driver.pod.name</td><td>spark-master-driver</td></tr><tr><td style="text-align:left;">spark.app.submitTime</td><td>1743202347472</td></tr><tr><td style="text-align:left;">spark.kubernetes.namespace</td><td>dew59</td></tr><tr><td style="text-align:left;">spark.sql.warehouse.dir</td><td>file:/home/dew59/ghcn-spark-analysis/notebooks/spark-warehouse</td></tr><tr><td style="text-align:left;">spark.fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net</td><td>"sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D"</td></tr><tr><td style="text-align:left;">spark.kubernetes.container.image.pullPolicy</td><td>IfNotPresent</td></tr><tr><td style="text-align:left;">spark.driver.memory</td><td>1g</td></tr><tr><td style="text-align:left;">spark.driver.extraJavaOptions</td><td>-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false -Dderby.system.home=/tmp/dew59/spark/</td></tr><tr><td style="text-align:left;">fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net</td><td>sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D</td></tr><tr><td style="text-align:left;">spark.app.startTime</td><td>1743202347582</td></tr><tr><td style="text-align:left;">spark.executor.instances</td><td>2</td></tr><tr><td style="text-align:left;">spark.executor.memory</td><td>1g</td></tr><tr><td style="text-align:left;">spark.serializer.objectStreamReset</td><td>100</td></tr><tr><td style="text-align:left;">spark.driver.maxResultSize</td><td>0</td></tr><tr><td style="text-align:left;">spark.submit.deployMode</td><td>client</td></tr><tr><td style="text-align:left;">spark.master</td><td>k8s://https://kubernetes.default.svc.cluster.local:443</td></tr><tr><td style="text-align:left;">spark.fs.azure</td><td>org.apache.hadoop.fs.azure.NativeAzureFileSystem</td></tr><tr><td style="text-align:left;">spark.app.name</td><td>dew59 (notebook)</td></tr><tr><td style="text-align:left;">spark.memory.fraction</td><td>0.1</td></tr><tr><td style="text-align:left;">spark.executor.id</td><td>driver</td></tr><tr><td style="text-align:left;">spark.app.id</td><td>spark-2c0750f6e52c48b29c0d0d25bd9bcf3a</td></tr><tr><td style="text-align:left;">spark.kub ...
# Spark App: dew59 (notebook)
# Master   : k8s://https://kubernetes.default.svc.cluster.local:443
# UI       : http://spark-master-svc:4045
# Version  : 3.5.1
#
# Spark Config:
# spark.kubernetes.executor.podNamePrefix = dew59-notebook-741e2595def4ed26
# spark.dynamicAllocation.enabled = false
# spark.fs.azure.sas.uco-user.madsstorage002.blob.core.windows.net = "sp=racwdl&st=2024-09-19T08:00:18Z&se=2025-09-19T16:00:18Z&spr=https&sv=2022-11-02&sr=c&sig=qtg6fCdoFz6k3EJLw7dA8D3D8wN0neAYw8yG4z4Lw2o%3D"
# spark.kubernetes.driver.pod.name = spark-master-driver
# spark.app.submitTime = 1743202347472
# spark.kubernetes.namespace = dew59
# spark.sql.warehouse.dir = file:/home/dew59/ghcn-spark-analysis/notebooks/spark-warehouse
# spark.fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net = "sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D"
# spark.kubernetes.container.image.pullPolicy = IfNotPresent
# spark.driver.memory = 1g
# spark.driver.extraJavaOptions = -Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false -Dderby.system.home=/tmp/dew59/spark/
# fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net = sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D
# spark.app.startTime = 1743202347582
# spark.executor.instances = 2
# spark.executor.memory = 1g
# spark.serializer.objectStreamReset = 100
# spark.driver.maxResultSize = 0
# spark.submit.deployMode = client
# spark.master = k8s://https://kubernetes.default.svc.cluster.local:443
# spark.fs.azure = org.apache.hadoop.fs.azure.NativeAzureFileSystem
# spark.app.name = dew59 (notebook)
# spark.memory.fraction = 0.1
# spark.executor.id = driver
# spark.app.id = spark-2c0750f6e52c48b29c0d0d25bd9bcf3a
# spark.kubernetes.memoryOverheadFactor = 0.3
# spark.driver.host = spark-master-svc
# spark.ui.port = ${env:SPARK_UI_PORT}
# spark.kubernetes.container.image = madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8
# spark.kubernetes.executor.podTemplateFile = /opt/spark/conf/executor-pod-template.yaml
# spark.rdd.compress = True
# spark.executor.extraJavaOptions = -Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false
# spark.cores.max = 2
# spark.driver.port = 7077
# spark.submit.pyFiles =
# spark.executor.cores = 1
# spark.sql.shuffle.partitions = 8
# spark.ui.showConsoleProgress = true
# spark.kubernetes.executor.container.image = madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8-1.0.02
# Spark App: dew59 (notebook)
# Master   : k8s://https://kubernetes.default.svc.cluster.local:443
# UI       : http://spark-master-svc:4045
# Version  : 3.5.1
#
# Spark Config:
# spark.kubernetes.executor.podNamePrefix = dew59-notebook-741e2595def4ed26
# spark.dynamicAllocation.enabled = false
# spark.fs.azure.sas.uco-user.madsstorage002.blob.core.windows.net = "sp=racwdl&st=2024-09-19T08:00:18Z&se=2025-09-19T16:00:18Z&spr=https&sv=2022-11-02&sr=c&sig=qtg6fCdoFz6k3EJLw7dA8D3D8wN0neAYw8yG4z4Lw2o%3D"
# spark.kubernetes.driver.pod.name = spark-master-driver
# spark.app.submitTime = 1743202347472
# spark.kubernetes.namespace = dew59
# spark.sql.warehouse.dir = file:/home/dew59/ghcn-spark-analysis/notebooks/spark-warehouse
# spark.fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net = "sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D"
# spark.kubernetes.container.image.pullPolicy = IfNotPresent
# spark.driver.memory = 1g
# spark.driver.extraJavaOptions = -Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false -Dderby.system.home=/tmp/dew59/spark/
# fs.azure.sas.campus-user.madsstorage002.blob.core.windows.net = sp=racwdl&st=2024-09-19T08:03:31Z&se=2025-09-19T16:03:31Z&spr=https&sv=2022-11-02&sr=c&sig=kMP%2BsBsRzdVVR8rrg%2BNbDhkRBNs6Q98kYY695XMRFDU%3D
# spark.app.startTime = 1743202347582
# spark.executor.instances = 2
# spark.executor.memory = 1g
# spark.serializer.objectStreamReset = 100
# spark.driver.maxResultSize = 0
# spark.submit.deployMode = client
# spark.master = k8s://https://kubernetes.default.svc.cluster.local:443
# spark.fs.azure = org.apache.hadoop.fs.azure.NativeAzureFileSystem
# spark.app.name = dew59 (notebook)
# spark.memory.fraction = 0.1
# spark.executor.id = driver
# spark.app.id = spark-2c0750f6e52c48b29c0d0d25bd9bcf3a
# spark.kubernetes.memoryOverheadFactor = 0.3
# spark.driver.host = spark-master-svc
# spark.ui.port = ${env:SPARK_UI_PORT}
# spark.kubernetes.container.image = madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8
# spark.kubernetes.executor.podTemplateFile = /opt/spark/conf/executor-pod-template.yaml
# spark.rdd.compress = True
# spark.executor.extraJavaOptions = -Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false
# spark.cores.max = 2
# spark.driver.port = 7077
# spark.submit.pyFiles =
# spark.executor.cores = 1
# spark.sql.shuffle.partitions = 8
# spark.ui.showConsoleProgress = true
# spark.kubernetes.executor.container.image = madsregistry001.azurecr.io/hadoop-spark:v3.3.5-openjdk-8-1.0.02

# %%
# Write your imports here or insert cells below

from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
# Use the hdfs command to explore the data in Azure Blob Storage

#! HADOOP_ROOT_LOGGER="WARNING" hdfs dfs -ls    wasbs://{azure_data_container_name}@{azure_account_name}.blob.core.windows.net/ghcnd/
#! HADOOP_ROOT_LOGGER="WARNING" hdfs dfs -ls    wasbs://{azure_data_container_name}@{azure_account_name}.blob.core.windows.net/ghcnd/daily/
! HADOOP_ROOT_LOGGER="WARNING" hdfs dfs -du -h   wasbs://{azure_data_container_name}@{azure_account_name}.blob.core.windows.net/ghcnd/
# Out:
# Found 5 items
# drwxrwxrwx   -          0 1970-01-01 12:00 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily
# -rwxrwxrwx   1       3659 2025-02-18 15:09 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-countries.txt
# -rwxrwxrwx   1   35218290 2025-02-18 15:09 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-inventory.txt
# -rwxrwxrwx   1       1086 2025-02-18 15:09 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-states.txt
# -rwxrwxrwx   1   11150502 2025-02-18 15:09 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-stations.txt
# Found 264 items
# -rwxrwxrwx   1    1385743 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1750.csv.gz
# -rwxrwxrwx   1       3358 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1763.csv.gz
# -rwxrwxrwx   1       3327 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1764.csv.gz
# -rwxrwxrwx   1       3335 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1765.csv.gz
# -rwxrwxrwx   1       3344 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1766.csv.gz
# -rwxrwxrwx   1       3356 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1767.csv.gz
# -rwxrwxrwx   1       3325 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1768.csv.gz
# -rwxrwxrwx   1       3418 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1769.csv.gz
# -rwxrwxrwx   1       3357 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1770.csv.gz
# -rwxrwxrwx   1       3373 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1771.csv.gz
# -rwxrwxrwx   1       3419 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1772.csv.gz
# -rwxrwxrwx   1       3368 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1773.csv.gz
# -rwxrwxrwx   1       3393 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1774.csv.gz
# -rwxrwxrwx   1       6365 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1775.csv.gz
# -rwxrwxrwx   1       6425 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1776.csv.gz
# -rwxrwxrwx   1       6424 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1777.csv.gz
# -rwxrwxrwx   1       6240 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1778.csv.gz
# -rwxrwxrwx   1       6144 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1779.csv.gz
# -rwxrwxrwx   1       6245 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1780.csv.gz
# -rwxrwxrwx   1       7799 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1781.csv.gz
# -rwxrwxrwx   1       7808 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1782.csv.gz
# -rwxrwxrwx   1       7920 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1783.csv.gz
# -rwxrwxrwx   1       7946 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1784.csv.gz
# -rwxrwxrwx   1       7804 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1785.csv.gz
# -rwxrwxrwx   1       7891 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1786.csv.gz
# -rwxrwxrwx   1       6336 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1787.csv.gz
# -rwxrwxrwx   1       6394 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1788.csv.gz
# -rwxrwxrwx   1       7773 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1789.csv.gz
# -rwxrwxrwx   1       7786 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1790.csv.gz
# -rwxrwxrwx   1       7734 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1791.csv.gz
# -rwxrwxrwx   1       7806 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1792.csv.gz
# -rwxrwxrwx   1       6342 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1793.csv.gz
# -rwxrwxrwx   1       7770 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1794.csv.gz
# -rwxrwxrwx   1       7843 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1795.csv.gz
# -rwxrwxrwx   1       7821 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1796.csv.gz
# -rwxrwxrwx   1       9239 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1797.csv.gz
# -rwxrwxrwx   1       9290 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1798.csv.gz
# -rwxrwxrwx   1       6351 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1799.csv.gz
# -rwxrwxrwx   1       7783 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1800.csv.gz
# -rwxrwxrwx   1       7801 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1801.csv.gz
# -rwxrwxrwx   1       9195 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1802.csv.gz
# -rwxrwxrwx   1       7892 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1803.csv.gz
# -rwxrwxrwx   1       8727 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1804.csv.gz
# -rwxrwxrwx   1       8901 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1805.csv.gz
# -rwxrwxrwx   1       8598 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1806.csv.gz
# -rwxrwxrwx   1       8725 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1807.csv.gz
# -rwxrwxrwx   1       8928 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1808.csv.gz
# -rwxrwxrwx   1       8778 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1809.csv.gz
# -rwxrwxrwx   1       8829 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1810.csv.gz
# -rwxrwxrwx   1       8932 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1811.csv.gz
# -rwxrwxrwx   1       8993 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1812.csv.gz
# -rwxrwxrwx   1       9264 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1813.csv.gz
# -rwxrwxrwx   1      10833 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1814.csv.gz
# -rwxrwxrwx   1      13884 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1815.csv.gz
# -rwxrwxrwx   1      13865 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1816.csv.gz
# -rwxrwxrwx   1      13758 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1817.csv.gz
# -rwxrwxrwx   1      13758 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1818.csv.gz
# -rwxrwxrwx   1      13690 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1819.csv.gz
# -rwxrwxrwx   1      13997 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1820.csv.gz
# -rwxrwxrwx   1      13792 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1821.csv.gz
# -rwxrwxrwx   1      14049 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1822.csv.gz
# -rwxrwxrwx   1      14745 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1823.csv.gz
# -rwxrwxrwx   1      18035 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1824.csv.gz
# -rwxrwxrwx   1      18101 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1825.csv.gz
# -rwxrwxrwx   1      18403 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1826.csv.gz
# -rwxrwxrwx   1      20855 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1827.csv.gz
# -rwxrwxrwx   1      20981 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1828.csv.gz
# -rwxrwxrwx   1      21141 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1829.csv.gz
# -rwxrwxrwx   1      21306 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1830.csv.gz
# -rwxrwxrwx   1      21319 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1831.csv.gz
# -rwxrwxrwx   1      22435 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1832.csv.gz
# -rwxrwxrwx   1      27262 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1833.csv.gz
# -rwxrwxrwx   1      27164 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1834.csv.gz
# -rwxrwxrwx   1      27546 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1835.csv.gz
# -rwxrwxrwx   1      29795 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1836.csv.gz
# -rwxrwxrwx   1      29334 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1837.csv.gz
# -rwxrwxrwx   1      31459 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1838.csv.gz
# -rwxrwxrwx   1      29361 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1839.csv.gz
# -rwxrwxrwx   1      35913 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1840.csv.gz
# -rwxrwxrwx   1      36864 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1841.csv.gz
# -rwxrwxrwx   1      39570 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1842.csv.gz
# -rwxrwxrwx   1      39535 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1843.csv.gz
# -rwxrwxrwx   1      43325 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1844.csv.gz
# -rwxrwxrwx   1      52256 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1845.csv.gz
# -rwxrwxrwx   1      49535 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1846.csv.gz
# -rwxrwxrwx   1      50847 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1847.csv.gz
# -rwxrwxrwx   1      50033 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1848.csv.gz
# -rwxrwxrwx   1      51977 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1849.csv.gz
# -rwxrwxrwx   1      51871 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1850.csv.gz
# -rwxrwxrwx   1      59192 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1851.csv.gz
# -rwxrwxrwx   1      63805 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1852.csv.gz
# -rwxrwxrwx   1      64356 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1853.csv.gz
# -rwxrwxrwx   1      64004 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1854.csv.gz
# -rwxrwxrwx   1      70710 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1855.csv.gz
# -rwxrwxrwx   1      81212 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1856.csv.gz
# -rwxrwxrwx   1      88910 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1857.csv.gz
# -rwxrwxrwx   1     122842 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1858.csv.gz
# -rwxrwxrwx   1     136813 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1859.csv.gz
# -rwxrwxrwx   1     146995 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1860.csv.gz
# -rwxrwxrwx   1     150606 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1861.csv.gz
# -rwxrwxrwx   1     145625 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1862.csv.gz
# -rwxrwxrwx   1     164239 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1863.csv.gz
# -rwxrwxrwx   1     164146 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1864.csv.gz
# -rwxrwxrwx   1     163927 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1865.csv.gz
# -rwxrwxrwx   1     212821 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1866.csv.gz
# -rwxrwxrwx   1     256701 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1867.csv.gz
# -rwxrwxrwx   1     269545 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1868.csv.gz
# -rwxrwxrwx   1     314469 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1869.csv.gz
# -rwxrwxrwx   1     360140 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1870.csv.gz
# -rwxrwxrwx   1     477098 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1871.csv.gz
# -rwxrwxrwx   1     650129 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1872.csv.gz
# -rwxrwxrwx   1     728688 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1873.csv.gz
# -rwxrwxrwx   1     815760 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1874.csv.gz
# -rwxrwxrwx   1     886014 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1875.csv.gz
# -rwxrwxrwx   1     965160 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1876.csv.gz
# -rwxrwxrwx   1    1077970 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1877.csv.gz
# -rwxrwxrwx   1    1274702 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1878.csv.gz
# -rwxrwxrwx   1    1461379 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1879.csv.gz
# -rwxrwxrwx   1    1847043 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1880.csv.gz
# -rwxrwxrwx   1    2208841 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1881.csv.gz
# -rwxrwxrwx   1    2512758 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1882.csv.gz
# -rwxrwxrwx   1    2775527 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1883.csv.gz
# -rwxrwxrwx   1    3303464 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1884.csv.gz
# -rwxrwxrwx   1    3745027 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1885.csv.gz
# -rwxrwxrwx   1    4102788 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1886.csv.gz
# -rwxrwxrwx   1    4605113 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1887.csv.gz
# -rwxrwxrwx   1    4958378 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1888.csv.gz
# -rwxrwxrwx   1    5388271 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1889.csv.gz
# -rwxrwxrwx   1    5878742 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1890.csv.gz
# -rwxrwxrwx   1    6170065 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1891.csv.gz
# -rwxrwxrwx   1    7118004 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1892.csv.gz
# -rwxrwxrwx   1   13052983 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1893.csv.gz
# -rwxrwxrwx   1   13929624 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1894.csv.gz
# -rwxrwxrwx   1   15036340 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1895.csv.gz
# -rwxrwxrwx   1   16204018 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1896.csv.gz
# -rwxrwxrwx   1   17474772 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1897.csv.gz
# -rwxrwxrwx   1   18225580 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1898.csv.gz
# -rwxrwxrwx   1   18953308 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1899.csv.gz
# -rwxrwxrwx   1   20251196 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1900.csv.gz
# -rwxrwxrwx   1   25767142 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1901.csv.gz
# -rwxrwxrwx   1   26736821 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1902.csv.gz
# -rwxrwxrwx   1   27302649 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1903.csv.gz
# -rwxrwxrwx   1   28201320 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1904.csv.gz
# -rwxrwxrwx   1   29632148 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1905.csv.gz
# -rwxrwxrwx   1   30289765 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1906.csv.gz
# -rwxrwxrwx   1   31144951 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1907.csv.gz
# -rwxrwxrwx   1   31867868 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1908.csv.gz
# -rwxrwxrwx   1   33519209 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1909.csv.gz
# -rwxrwxrwx   1   34622865 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1910.csv.gz
# -rwxrwxrwx   1   35904462 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1911.csv.gz
# -rwxrwxrwx   1   37263226 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1912.csv.gz
# -rwxrwxrwx   1   38255770 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1913.csv.gz
# -rwxrwxrwx   1   39485528 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1914.csv.gz
# -rwxrwxrwx   1   40658560 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1915.csv.gz
# -rwxrwxrwx   1   42029487 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1916.csv.gz
# -rwxrwxrwx   1   42252301 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1917.csv.gz
# -rwxrwxrwx   1   41304535 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1918.csv.gz
# -rwxrwxrwx   1   40799997 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1919.csv.gz
# -rwxrwxrwx   1   41033429 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1920.csv.gz
# -rwxrwxrwx   1   41324111 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1921.csv.gz
# -rwxrwxrwx   1   42113624 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1922.csv.gz
# -rwxrwxrwx   1   42862524 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1923.csv.gz
# -rwxrwxrwx   1   43710214 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1924.csv.gz
# -rwxrwxrwx   1   44015966 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1925.csv.gz
# -rwxrwxrwx   1   45226774 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1926.csv.gz
# -rwxrwxrwx   1   46033600 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1927.csv.gz
# -rwxrwxrwx   1   46580018 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1928.csv.gz
# -rwxrwxrwx   1   47573559 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1929.csv.gz
# -rwxrwxrwx   1   48987101 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1930.csv.gz
# -rwxrwxrwx   1   50624633 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1931.csv.gz
# -rwxrwxrwx   1   51705273 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1932.csv.gz
# -rwxrwxrwx   1   52178613 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1933.csv.gz
# -rwxrwxrwx   1   52521149 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1934.csv.gz
# -rwxrwxrwx   1   53488183 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1935.csv.gz
# -rwxrwxrwx   1   56768695 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1936.csv.gz
# -rwxrwxrwx   1   58175289 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1937.csv.gz
# -rwxrwxrwx   1   59344873 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1938.csv.gz
# -rwxrwxrwx   1   61148235 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1939.csv.gz
# -rwxrwxrwx   1   63463421 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1940.csv.gz
# -rwxrwxrwx   1   65375485 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1941.csv.gz
# -rwxrwxrwx   1   67537465 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1942.csv.gz
# -rwxrwxrwx   1   68405592 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1943.csv.gz
# -rwxrwxrwx   1   70192973 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1944.csv.gz
# -rwxrwxrwx   1   72659632 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1945.csv.gz
# -rwxrwxrwx   1   73148444 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1946.csv.gz
# -rwxrwxrwx   1   74970819 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1947.csv.gz
# -rwxrwxrwx   1   89145605 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1948.csv.gz
# -rwxrwxrwx   1  101758958 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1949.csv.gz
# -rwxrwxrwx   1  104856670 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1950.csv.gz
# -rwxrwxrwx   1  108201081 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1951.csv.gz
# -rwxrwxrwx   1  109667528 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1952.csv.gz
# -rwxrwxrwx   1  111171866 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1953.csv.gz
# -rwxrwxrwx   1  113330494 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1954.csv.gz
# -rwxrwxrwx   1  115757071 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1955.csv.gz
# -rwxrwxrwx   1  117984088 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1956.csv.gz
# -rwxrwxrwx   1  120673205 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1957.csv.gz
# -rwxrwxrwx   1  121914900 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1958.csv.gz
# -rwxrwxrwx   1  124376950 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1959.csv.gz
# -rwxrwxrwx   1  126849252 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1960.csv.gz
# -rwxrwxrwx   1  130750539 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1961.csv.gz
# -rwxrwxrwx   1  133559230 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1962.csv.gz
# -rwxrwxrwx   1  136585486 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1963.csv.gz
# -rwxrwxrwx   1  137581099 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1964.csv.gz
# -rwxrwxrwx   1  142018261 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1965.csv.gz
# -rwxrwxrwx   1  143937982 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1966.csv.gz
# -rwxrwxrwx   1  145306876 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1967.csv.gz
# -rwxrwxrwx   1  144896387 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1968.csv.gz
# -rwxrwxrwx   1  146762160 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1969.csv.gz
# -rwxrwxrwx   1  147692050 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1970.csv.gz
# -rwxrwxrwx   1  142221845 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1971.csv.gz
# -rwxrwxrwx   1  141305619 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1972.csv.gz
# -rwxrwxrwx   1  148100923 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1973.csv.gz
# -rwxrwxrwx   1  149378829 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1974.csv.gz
# -rwxrwxrwx   1  148905604 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1975.csv.gz
# -rwxrwxrwx   1  148764292 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1976.csv.gz
# -rwxrwxrwx   1  148575501 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1977.csv.gz
# -rwxrwxrwx   1  148815187 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1978.csv.gz
# -rwxrwxrwx   1  149117704 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1979.csv.gz
# -rwxrwxrwx   1  149579207 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1980.csv.gz
# -rwxrwxrwx   1  152656825 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1981.csv.gz
# -rwxrwxrwx   1  154508476 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1982.csv.gz
# -rwxrwxrwx   1  155940158 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1983.csv.gz
# -rwxrwxrwx   1  154313147 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1984.csv.gz
# -rwxrwxrwx   1  152811879 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1985.csv.gz
# -rwxrwxrwx   1  151770851 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1986.csv.gz
# -rwxrwxrwx   1  151809884 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1987.csv.gz
# -rwxrwxrwx   1  152626966 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1988.csv.gz
# -rwxrwxrwx   1  153053088 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1989.csv.gz
# -rwxrwxrwx   1  153157679 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1990.csv.gz
# -rwxrwxrwx   1  153852159 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1991.csv.gz
# -rwxrwxrwx   1  154026142 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1992.csv.gz
# -rwxrwxrwx   1  152865318 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1993.csv.gz
# -rwxrwxrwx   1  151844762 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1994.csv.gz
# -rwxrwxrwx   1  151469358 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1995.csv.gz
# -rwxrwxrwx   1  151756945 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1996.csv.gz
# -rwxrwxrwx   1  150454010 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1997.csv.gz
# -rwxrwxrwx   1  153494337 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1998.csv.gz
# -rwxrwxrwx   1  156271670 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/1999.csv.gz
# -rwxrwxrwx   1  158226488 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2000.csv.gz
# -rwxrwxrwx   1  160670036 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2001.csv.gz
# -rwxrwxrwx   1  162275809 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2002.csv.gz
# -rwxrwxrwx   1  165928854 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2003.csv.gz
# -rwxrwxrwx   1  168459055 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2004.csv.gz
# -rwxrwxrwx   1  165289423 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2005.csv.gz
# -rwxrwxrwx   1  171894892 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2006.csv.gz
# -rwxrwxrwx   1  174934788 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2007.csv.gz
# -rwxrwxrwx   1  182624806 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2008.csv.gz
# -rwxrwxrwx   1  185641000 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2009.csv.gz
# -rwxrwxrwx   1  187293865 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2010.csv.gz
# -rwxrwxrwx   1  177949864 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2011.csv.gz
# -rwxrwxrwx   1  175262367 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2012.csv.gz
# -rwxrwxrwx   1  170236479 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2013.csv.gz
# -rwxrwxrwx   1  168607573 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2014.csv.gz
# -rwxrwxrwx   1  171192339 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2015.csv.gz
# -rwxrwxrwx   1  172621542 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2016.csv.gz
# -rwxrwxrwx   1  172257484 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2017.csv.gz
# -rwxrwxrwx   1  172359764 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2018.csv.gz
# -rwxrwxrwx   1  171131311 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2019.csv.gz
# -rwxrwxrwx   1  172132828 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2020.csv.gz
# -rwxrwxrwx   1  175050475 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2021.csv.gz
# -rwxrwxrwx   1  175205910 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2022.csv.gz
# -rwxrwxrwx   1  174726829 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2023.csv.gz
# -rwxrwxrwx   1  168485088 2025-02-18 15:13 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2024.csv.gz
# -rwxrwxrwx   1   17061071 2025-02-18 15:12 wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2025.csv.gz
# 3.6 K   3.6 K   wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-countries.txt
# 1.1 K   1.1 K   wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-states.txt
# 10.6 M  10.6 M  wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-stations.txt
# 13.0 G  13.0 G  wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily
# 33.6 M  33.6 M  wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-inventory.txt

# %%
# Define the input path for the last year in daily

daily_relative_path = f'ghcnd/daily/2025.csv.gz'
daily_path = f'wasbs://{azure_data_container_name}@{azure_account_name}.blob.core.windows.net/{daily_relative_path}'

print(daily_path)
# Out:
# wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/daily/2025.csv.gz

# %%
# Load a subset of the last year in daily into Spark from Azure Blob Storage using spark.read.csv

daily = spark.read.csv(daily_path).limit(1000)

print(type(daily))
daily.printSchema()
print(daily)
daily.show(20, False)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string]
# +-----------+--------+----+---+----+----+---+----+
# |_c0        |_c1     |_c2 |_c3|_c4 |_c5 |_c6|_c7 |
# +-----------+--------+----+---+----+----+---+----+
# |ASN00037106|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00037115|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00037118|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00037120|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00038010|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00038026|20250101|TMAX|419|NULL|NULL|a  |NULL|
# |ASN00038026|20250101|TMIN|226|NULL|NULL|a  |NULL|
# |ASN00038026|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00038026|20250101|TAVG|346|H   |NULL|S  |NULL|
# |ASN00004028|20250101|DAPR|2  |NULL|NULL|a  |NULL|
# |ASN00004028|20250101|DATN|2  |NULL|NULL|a  |NULL|
# |ASN00004028|20250101|MDPR|250|NULL|NULL|a  |NULL|
# |ASN00004028|20250101|MDTN|228|NULL|NULL|a  |NULL|
# |ASN00004032|20250101|TMAX|352|NULL|NULL|a  |NULL|
# |ASN00004032|20250101|TMIN|227|NULL|NULL|a  |NULL|
# |ASN00004032|20250101|TAVG|308|H   |NULL|S  |NULL|
# |ASN00004038|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00004039|20250101|PRCP|240|NULL|NULL|a  |NULL|
# |ASN00044038|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# |ASN00044045|20250101|PRCP|0  |NULL|NULL|a  |NULL|
# +-----------+--------+----+---+----+----+---+----+
# only showing top 20 rows

# %%
# Define the input path for stations

stations_relative_path = f'ghcnd/ghcnd-stations.txt'
stations_path = f'wasbs://{azure_data_container_name}@{azure_account_name}.blob.core.windows.net/{stations_relative_path}'

print(stations_path)
# Out:
# wasbs://campus-data@madsstorage002.blob.core.windows.net/ghcnd/ghcnd-stations.txt

# %%
# Load the stations metadata into Spark from Azure Blob Storage using spark.read.text without any other processing

stations = spark.read.text(stations_path).limit(1000)

print(type(stations))
stations.printSchema()
print(stations)
stations.show(20, False)
# Out:
# <class 'pyspark.sql.dataframe.DataFrame'>
# root
#  |-- value: string (nullable = true)
#
# DataFrame[value: string]
# +-------------------------------------------------------------------------------------+
# |value                                                                                |
# +-------------------------------------------------------------------------------------+
# |ACW00011604  17.1167  -61.7833   10.1    ST JOHNS COOLIDGE FLD                       |
# |ACW00011647  17.1333  -61.7833   19.2    ST JOHNS                                    |
# |AE000041196  25.3330   55.5170   34.0    SHARJAH INTER. AIRP            GSN     41196|
# |AEM00041194  25.2550   55.3640   10.4    DUBAI INTL                             41194|
# |AEM00041217  24.4330   54.6510   26.8    ABU DHABI INTL                         41217|
# |AEM00041218  24.2620   55.6090  264.9    AL AIN INTL                            41218|
# |AF000040930  35.3170   69.0170 3366.0    NORTH-SALANG                   GSN     40930|
# |AFM00040938  34.2100   62.2280  977.2    HERAT                                  40938|
# |AFM00040948  34.5660   69.2120 1791.3    KABUL INTL                             40948|
# |AFM00040990  31.5000   65.8500 1010.0    KANDAHAR AIRPORT                       40990|
# |AG000060390  36.7167    3.2500   24.0    ALGER-DAR EL BEIDA             GSN     60390|
# |AG000060590  30.5667    2.8667  397.0    EL-GOLEA                       GSN     60590|
# |AG000060611  28.0500    9.6331  561.0    IN-AMENAS                      GSN     60611|
# |AG000060680  22.8000    5.4331 1362.0    TAMANRASSET                    GSN     60680|
# |AGE00135039  35.7297    0.6500   50.0    ORAN-HOPITAL MILITAIRE                      |
# |AGE00147704  36.9700    7.7900  161.0    ANNABA-CAP DE GARDE                         |
# |AGE00147705  36.7800    3.0700   59.0    ALGIERS-VILLE/UNIVERSITE                    |
# |AGE00147706  36.8000    3.0300  344.0    ALGIERS-BOUZAREAH                           |
# |AGE00147707  36.8000    3.0400   38.0    ALGIERS-CAP CAXINE                          |
# |AGE00147708  36.7200    4.0500  222.0    TIZI OUZOU                             60395|
# +-------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# Define an output path as an exmaple

output_relative_path = f'{username}/stations'
output_path = f'wasbs://{azure_user_container_name}@{azure_account_name}.blob.core.windows.net/{output_relative_path}'

print(output_path)
# Out:
# wasbs://campus-user@madsstorage002.blob.core.windows.net/dew59/stations

# %%
# Save the stations metadata to Azure Blob Storage from Spark

stations.write.mode("overwrite").text(output_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Save the stations metadata to Azure Blob Storage from Spark
# ----> 3 stations.write.mode("overwrite").text(output_path)
#
# NameError: name 'stations' is not defined

# %%
# Use the hdfs command to explore the data in Azure Blob Storage

# !hdfs dfs -ls wasbs://{azure_user_container_name}@{azure_account_name}.blob.core.windows.net/{username}/stations/
# Out:
# 2025-03-26 16:58:51,456 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 2025-03-26 16:58:51,725 INFO impl.MetricsConfig: Loaded properties from hadoop-metrics2.properties
# 2025-03-26 16:58:51,770 INFO impl.MetricsSystemImpl: Scheduled Metric snapshot period at 10 second(s).
# 2025-03-26 16:58:51,770 INFO impl.MetricsSystemImpl: azure-file-system metrics system started
# Found 2 items
# -rw-r--r--   1 dew59 supergroup          0 2025-03-26 08:51 wasbs://campus-user@madsstorage002.blob.core.windows.net/dew59/stations/_SUCCESS
# -rw-r--r--   1 dew59 supergroup      86000 2025-03-26 08:51 wasbs://campus-user@madsstorage002.blob.core.windows.net/dew59/stations/part-00000-d05f6d0c-3adc-4399-ac77-2b0fb22e760b-c000.txt
# 2025-03-26 16:58:52,146 INFO impl.MetricsSystemImpl: Stopping azure-file-system metrics system...
# 2025-03-26 16:58:52,146 INFO impl.MetricsSystemImpl: azure-file-system metrics system stopped.
# 2025-03-26 16:58:52,146 INFO impl.MetricsSystemImpl: azure-file-system metrics system shutdown complete.

# %%
# Run this cell before closing the notebook or kill your spark application by hand using the link in the Spark UI

stop_spark()
# Out:
# 25/03/26 16:59:45 WARN ExecutorPodsWatchSnapshotSource: Kubernetes client has been closed.
# <p><b>Spark</b></p><p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>dew59 (notebook)</code> is under the completed applications section in the Spark UI.</p><ul><li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li></ul>

# %%
# Run this cell to import pyspark and to define start_spark() and stop_spark()

import findspark

findspark.init()

import getpass
import pandas as pd  
import pyspark
import random
import re

from IPython.display import display, HTML
from pyspark import SparkContext
from pyspark.sql import SparkSession


# Functions used below

def dict_to_html(d):
    """Convert a Python dictionary into a two column table for display.
    """

    html = []

    html.append(f'<table width="100%" style="width:100%; font-family: monospace;">')
    for k, v in d.items():
        html.append(f'<tr><td style="text-align:left;">{k}</td><td>{v}</td></tr>')
    html.append(f'</table>')

    return ''.join(html)


def show_as_html(df, n=20):
    """Leverage existing pandas jupyter integration to show a spark dataframe as html.
    
    Args:
        n (int): number of rows to show (default: 20)
    """

    display(df.limit(n).toPandas())

        
def display_spark():
    """Display the status of the active Spark session if one is currently running.
    """
    
    if 'spark' in globals() and 'sc' in globals():

        name = sc.getConf().get("spark.app.name")
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:green">active</span></b>, look for <code>{name}</code> under the running applications section in the Spark UI.</p>',
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'<li><a href="{sc.uiWebUrl}" target="_blank">Spark Application UI</a></li>',  # DEE:
            f'</ul>',
            f'<p><b>Config</b></p>',
            dict_to_html(dict(sc.getConf().getAll())),
            f'<p><b>Notes</b></p>',
            f'<ul>',
            f'<li>The spark session <code>spark</code> and spark context <code>sc</code> global variables have been defined by <code>start_spark()</code>.</li>',
            f'<li>Please run <code>stop_spark()</code> before closing the notebook or restarting the kernel or kill <code>{name}</code> by hand using the link in the Spark UI.</li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))
        
    else:
        
        html = [
            f'<p><b>Spark</b></p>',
            f'<p>The spark session is <b><span style="color:red">stopped</span></b>, confirm that <code>{username() + " (jupyter)"}</code> is under the completed applications section in the Spark UI.</p>',  # DEE:
            f'<ul>',
            f'<li><a href="http://mathmadslinux2p.canterbury.ac.nz:8080/" target="_blank">Spark UI</a></li>',
            f'</ul>',
        ]
        display(HTML(''.join(html)))


# Functions to start and stop spark

def start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1):
    """Start a new Spark session and define globals for SparkSession (spark) and SparkContext (sc).
    
    Args:
        executor_instances (int): number of executors (default: 2)
        executor_cores (int): number of cores per executor (default: 1)
        worker_memory (float): worker memory (default: 1)
        master_memory (float): master memory (default: 1)
    """

    global spark
    global sc

    user = username()  # DEE:
    
    cores = executor_instances * executor_cores
    partitions = cores * 4
    port = 4000 + random.randint(1, 999)

    spark = (
        SparkSession.builder
        .master("spark://masternode2:7077")  # DEE:
        .config("spark.driver.extraJavaOptions", f"-Dderby.system.home=/tmp/{user}/spark/")  # DEE:
        .config("spark.dynamicAllocation.enabled", "false")
        .config("spark.executor.instances", str(executor_instances))
        .config("spark.executor.cores", str(executor_cores))
        .config("spark.cores.max", str(cores))
        .config("spark.executor.memory", f"{worker_memory}g")  # DEE:
        .config("spark.driver.memory", f"{master_memory}g")  # DEE:
        .config("spark.driver.maxResultSize", "0")
        .config("spark.sql.shuffle.partitions", str(partitions))
        .config("spark.ui.port", str(port))  # DEE:
        .appName(user + " (jupyter)")  # DEE:
        .getOrCreate()
    )
    sc = SparkContext.getOrCreate()
    
    display_spark()

    
def stop_spark():
    """Stop the active Spark session and delete globals for SparkSession (spark) and SparkContext (sc).
    """

    global spark
    global sc

    if 'spark' in globals() and 'sc' in globals():

        spark.stop()

        del spark
        del sc

    display_spark()


# Make css changes to improve spark output readability

html = [
    '<style>',
    'pre { white-space: pre !important; }',
    'table.dataframe td { white-space: nowrap !important; }',
    'table.dataframe thead th:first-child, table.dataframe tbody th { display: none; }',
    '</style>',
]
display(HTML(''.join(html)))

# %%
from matplotlib import pyplot as plt  # DEE:
import numpy as np  # DEE:
import os  # DEE:
from pyspark.sql import Row, DataFrame, Window, functions as F  # DEE:
from pyspark.sql.types import *

# %%
# Show the structure of the GNCHD data  # DEE:
! hdfs dfs -ls /data/ghcnd  # DEE:

# %%
# Show the structure of daily part and export to txt file for fulture analysis  # DEE:
! hdfs dfs -ls /data/ghcnd/daily > ../supplementary/daily_folder_info.txt  # DEE:

# %%
# Load the daily file structure data and make a plot   # DEE:
daily_folder_info_path = "../supplementary/daily_folder_info.txt"  # DEE:
with open(daily_folder_info_path, 'r') as file:  # DEE:
    lines = file.readlines()[1:]  # DEE:
daily_year_size = []  # DEE:
daily_year = []  # DEE:
for line in lines:  # DEE:
    # file size of daily transfer to MB, and save to list  # DEE:
    daily_year_size.append(int(line[27:38].strip())/1024/1024)  # DEE:
    # daily year save to list  # DEE:
    daily_year.append(int(line[-12:-8].strip()))  # DEE:
    
fig, ax = plt.subplots(figsize=(12, 6))  # DEE:
ax.plot(daily_year, daily_year_size)  # DEE:
# Set title  # DEE:
ax.set_title('"daily" File Size Trend by Year (1750-2024)', fontsize=16, fontweight='bold')  # DEE:
# Set x-axis label  # DEE:
ax.set_xlabel('Year', fontsize=12)  # DEE:
# Set y-axis label  # DEE:
ax.set_ylabel('File Size (MB)', fontsize=12)  # DEE:
# Adjust x-axis ticks  # DEE:
ax.set_xticks(range(1750, 2024, 15))  # Show a tick every 15 years  # DEE:
plt.xticks(rotation=45, ha='right')  # DEE:
# Add grid for better readability  # DEE:
ax.grid(True, linestyle='--', alpha=0.7)  # DEE:
plt.savefig('../supplementary/historical_file_size_trend.png', dpi=300, bbox_inches='tight')  # DEE:

plt.show()  # DEE:

# %%
# Explore the different file size in GHCND  # DEE:
! hdfs dfs -du /data/ghcnd  # DEE:

# %%
start_spark(executor_instances=2, executor_cores=1, worker_memory=1, master_memory=1)
pprint_sc_context(sc)

# %%
# Define schma for Daily  # DEE:
daily_schema = StructType([  # DEE:
    StructField("ID", StringType(), nullable=False),  # DEE:
    StructField("DATE", StringType(), nullable=False),  # DEE:
    StructField("ELEMENT", StringType(), nullable=False),  # DEE:
    StructField("VALUE", FloatType(), nullable=False),  # DEE:
    StructField("MEASUREMENT_FLAG", StringType(), nullable=True),  # DEE:
    StructField("QUALITY_FLAG", StringType(), nullable=True),  # DEE:
    StructField("SOURCE_FLAG", StringType(), nullable=True),  # DEE:
    StructField("OBSERVATION_TIME", StringType(), nullable=True)  # DEE:
])  # DEE:

# %%
# Read 1000 rows of 2023 daily file  # DEE:
daily_df = spark.read.format("csv") \  # DEE:
    .option("header", "false") \  # DEE:
    .option("sep", ",") \  # DEE:
    .schema(daily_schema) \  # DEE:
    .load("hdfs:///data/ghcnd/daily/2023.csv.gz") \  # DEE:
    .limit(1000)  # DEE:

# Parse the DATE column  # DEE:
daily_df = daily_df.withColumn("DATE", F.to_date(F.col("DATE"), "yyyyMMdd"))  # DEE:

# Parse the OBSERVATION_TIME column  # DEE:
daily_df = daily_df.withColumn("OBSERVATION_TIME",   # DEE:
    F.to_timestamp(F.concat(F.lit("1970-01-01 "), F.col("OBSERVATION_TIME")), "yyyy-MM-dd HHmm"))  # DEE:
daily_df = daily_df.withColumn("OBSERVATION_TIME",   # DEE:
    F.date_format(F.col("OBSERVATION_TIME"), "HH:mm"))  # DEE:

# show the sample of data and print the schema  # DEE:
show_as_html(daily_df)  # DEE:
daily_df.printSchema()  # DEE:

# %%
# Read the stations file  # DEE:
stations_df = spark.read.text("hdfs:///data/ghcnd/ghcnd-stations.txt")  # DEE:

# Parse the fixed-width formatted data  # DEE:
stations_df = stations_df.select(  # DEE:
    F.trim(F.substring("value", 1, 11)).alias("ID"),  # DEE:
    F.trim(F.substring("value", 13, 8)).cast("float").alias("LATITUDE"),  # DEE:
    F.trim(F.substring("value", 22, 9)).cast("float").alias("LONGITUDE"),  # DEE:
    F.trim(F.substring("value", 32, 6)).cast("float").alias("ELEVATION"),  # DEE:
    F.trim(F.substring("value", 39, 2)).alias("STATE"),  # DEE:
    F.trim(F.substring("value", 42, 30)).alias("NAME"),  # DEE:
    F.trim(F.substring("value", 73, 3)).alias("GSN_FLAG"),  # DEE:
    F.trim(F.substring("value", 77, 3)).alias("HCN_CRN_FLAG"),  # DEE:
    F.trim(F.substring("value", 81, 5)).cast("int").alias("WMO_ID")  # DEE:
)

show_as_html(stations_df)  # DEE:

# %%
# Read the countries file  # DEE:
countries_df = spark.read.text("hdfs:///data/ghcnd/ghcnd-countries.txt")  # DEE:

# Parse the fixed-width formatted data  # DEE:
countries_df = countries_df.select(  # DEE:
    F.trim(F.substring("value", 1, 2)).alias("CODE"),  # DEE:
    F.trim(F.substring("value", 4, 61)).alias("NAME")  # DEE:
)

show_as_html(countries_df)  # DEE:

# %%
# Read the states file  # DEE:
states_df = spark.read.text("hdfs:///data/ghcnd/ghcnd-states.txt")  # DEE:

# Parse the fixed-width formatted data  # DEE:
states_df = states_df.select(  # DEE:
    F.trim(F.substring("value", 1, 2)).alias("CODE"),  # DEE:
    F.trim(F.substring("value", 4, 47)).alias("NAME")  # DEE:
)

show_as_html(states_df)  # DEE:

# %%
# Read the inventory file  # DEE:
inventory_df = spark.read.text("hdfs:///data/ghcnd/ghcnd-inventory.txt")  # DEE:

# Parse the fixed-width formatted data  # DEE:
inventory_df = inventory_df.select(  # DEE:
    F.trim(F.substring("value", 1, 11)).alias("ID"),  # DEE:
    F.trim(F.substring("value", 13, 8)).cast("float").alias("LATITUDE"),  # DEE:
    F.trim(F.substring("value", 22, 9)).cast("float").alias("LONGITUDE"),  # DEE:
    F.trim(F.substring("value", 32, 4)).alias("ELEMENT"),  # DEE:
    F.trim(F.substring("value", 37, 4)).cast("int").alias("FIRSTYEAR"),  # DEE:
    F.trim(F.substring("value", 42, 4)).cast("int").alias("LASTYEAR")  # DEE:
)

show_as_html(inventory_df)  # DEE:

# %%
# Count rows in stations table  # DEE:
stations_count = stations_df.count()  # DEE:
print(f"Number of rows in stations table: {stations_count}")  # DEE:

# Count rows in states table  # DEE:
states_count = states_df.count()  # DEE:
print(f"Number of rows in states table: {states_count}")  # DEE:

# Count rows in countries table  # DEE:
countries_count = countries_df.count()  # DEE:
print(f"Number of rows in countries table: {countries_count}")  # DEE:

# Count rows in inventory table  # DEE:
inventory_count = inventory_df.count()  # DEE:
print(f"Number of rows in inventory table: {inventory_count}")  # DEE:

# %%
# Get unique station IDs from inventory table  # DEE:
inventory_stations = inventory_df.select("ID").distinct()  # DEE:

# Get unique station IDs from stations table  # DEE:
stations_ids = stations_df.select("ID").distinct()  # DEE:

# Find the overlap of stations  # DEE:
stations_in_inventory_not_in_stations = inventory_stations.subtract(stations_ids)  # DEE:

print(f"There are {stations_in_inventory_not_in_stations.count()} stations in the inventory table that are not in the stations table.")  # DEE:

# %%
stop_spark()
